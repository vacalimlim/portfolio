# %% [markdown]
# # Portfolio #1

# %% [markdown]
# Direction: Ask the user for different inputs involving different data types like numbers, strings etc. Afterwards, print back the inputs the user provided in a sentence.

# %%
order = "McSpicy" #input("Enter order: ")
quantity = 10 #int(input("Quantity: "))
price = 150 #int(input("Price: "))
totalAmount = quantity*price
print(f"You ordered {quantity} {order:<28s} amounting {totalAmount:9d} pesos")
totalAmount *= 10
order *= 2
print(f"You ordered {quantity} {order:<28s} amounting {totalAmount:>9.2f} pesos")
totalAmount *= 10
order *= 2
print(f"You ordered {quantity} {order:<28s} amounting {totalAmount:>9.2f} pesos")
# Out:
# You ordered 10 McSpicy                      amounting      1500 pesos
# You ordered 10 McSpicyMcSpicy               amounting  15000.00 pesos
# You ordered 10 McSpicyMcSpicyMcSpicyMcSpicy amounting 150000.00 pesos
